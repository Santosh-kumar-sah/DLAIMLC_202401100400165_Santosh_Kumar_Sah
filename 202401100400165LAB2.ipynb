# %%
import numpy as np

def step(z):
    return 1 if z >= 0 else 0

x = np.array([0.50, 0.60, 0.70])
w = np.array([0.4, 0.3, 0.5])
b = -0.2
n = 0.01
y = 1


z = np.dot(w, x) + b
y_pred = step(z)

# %%
error = y - y_pred

w = w + n * error * x
b = b + n * error

# %%
y_pred
# Out:
# 1
